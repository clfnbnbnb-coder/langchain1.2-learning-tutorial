# %% [markdown]
# # Agent的记忆测试
#
# ## 情况1：

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os



# 1、提供大模型
load_dotenv(override=True)

model = init_chat_model(
    model="qwen3.7-plus",
    model_provider="openai",
    profile={"max_input_tokens": 128_000},
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    # temperature=1.5,
    base_url=os.getenv("DASHSCOPE_BASE_URL"),
    extra_body={"enable_thinking": False},
    # max_tokens=10,
)

# %%
from langchain_core.messages import HumanMessage, AIMessage
from langchain.agents import create_agent

messages1 = [
    HumanMessage("你好，我叫小明"),
    AIMessage("你好，小明"),
    HumanMessage("你用一句话介绍自己")
]

agent = create_agent(
    model=model,
    tools=[]
)

response1 = agent.invoke({"messages" : messages1})

for msg in response1["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 你好，我叫小明
# ================================== Ai Message ==================================
#
# 你好，小明
# ================================ Human Message =================================
#
# 你用一句话介绍自己
# ================================== Ai Message ==================================
#
# 我是通义千问，一个由阿里云研发的大语言模型，致力于为你提供智能、高效且贴心的帮助。

# %%
messages2 = [HumanMessage("我叫什么名字？")]

response2 = agent.invoke({"messages" : messages2})

for msg in response2["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 我叫什么名字？
# ================================== Ai Message ==================================
#
# 我不知道您的名字。
#
# 作为一个人工智能助手，我无法获取您的个人身份信息，除非您在当前的对话中主动告诉我。如果您愿意，可以告诉我您希望我怎么称呼您！

# %% [markdown]
# ## 情况2：

# %%
messages3 = [
    HumanMessage("你好，我叫小明"),
    AIMessage("你好，小明"),
    HumanMessage("你用一句话介绍自己"),
    AIMessage("我是通义千问，一个由阿里云研发的大语言模型，致力于为你提供智能、高效且贴心的帮助。"),
    HumanMessage("我叫什么名字？")
]

agent = create_agent(
    model=model,
    tools=[]
)

response3 = agent.invoke({"messages": messages3})

for msg in response3["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 你好，我叫小明
# ================================== Ai Message ==================================
#
# 你好，小明
# ================================ Human Message =================================
#
# 你用一句话介绍自己
# ================================== Ai Message ==================================
#
# 我是通义千问，一个由阿里云研发的大语言模型，致力于为你提供智能、高效且贴心的帮助。
# ================================ Human Message =================================
#
# 我叫什么名字？
# ================================== Ai Message ==================================
#
# 你叫小明。
