# %% [markdown]
# # ChatPromptTemplate的使用
#
# ## 1、ChatPromptTemplate的实例化
#
# ### 1.1 from_messages() --推荐
#
# 举例：

# %%
from langchain_core.prompts import ChatPromptTemplate

Chat_Prompt_Template = ChatPromptTemplate.from_messages([
    ("system","你是一个友好的AI助手，你的名字叫{name}"),
    ("user","你好，最近怎么样？"),
    ("ai","我很好，谢谢"),
    ("user","{user_input}"),
])

# 调用
result = Chat_Prompt_Template.invoke({"name":"卢本伟", "user_input":"2 + 2 = ？"})
print(result)
# Out:
# messages=[SystemMessage(content='你是一个友好的AI助手，你的名字叫卢本伟', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，最近怎么样？', additional_kwargs={}, response_metadata={}), AIMessage(content='我很好，谢谢', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='2 + 2 = ？', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ### 1.2 使用实例初始化方法
#
# 举例：

# %%
from langchain_core.prompts import ChatPromptTemplate

Chat_Prompt_Template = ChatPromptTemplate([
    ("system","你是一个友好的AI助手，你的名字叫{name}"),
    ("user","你好，最近怎么样？"),
    ("ai","我很好，谢谢"),
    ("user","{user_input}"),
])

# 调用
result = Chat_Prompt_Template.invoke({"name":"卢本伟", "user_input":"2 + 2 = ？"})
print(result)
# Out:
# messages=[SystemMessage(content='你是一个友好的AI助手，你的名字叫卢本伟', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，最近怎么样？', additional_kwargs={}, response_metadata={}), AIMessage(content='我很好，谢谢', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='2 + 2 = ？', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ## 2、ChatPromptTemplate的调用
#
# ### 2.1 invoke()
#
# 传入参数：字典列表：返回值类型：ChatPromptValue
#
# 举例：

# %%
from langchain_core.prompts import ChatPromptTemplate

Chat_Prompt_Template = ChatPromptTemplate.from_messages([
    ("system","你是一个友好的AI助手，你的名字叫{name}"),
    ("user","你好，最近怎么样？"),
    ("ai","我很好，谢谢"),
    ("user","{user_input}"),
])

# 调用
result = Chat_Prompt_Template.invoke({"name":"卢本伟", "user_input":"2 + 2 = ？"})
print(result)
print(type(result))
# Out:
# messages=[SystemMessage(content='你是一个友好的AI助手，你的名字叫卢本伟', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，最近怎么样？', additional_kwargs={}, response_metadata={}), AIMessage(content='我很好，谢谢', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='2 + 2 = ？', additional_kwargs={}, response_metadata={})]
# <class 'langchain_core.prompt_values.ChatPromptValue'>

# %% [markdown]
# ### 2.2 format()
#
# 参数类型：变量值：返回值类型：字符串
#
# 举例：

# %%
from langchain_core.prompts import ChatPromptTemplate

Chat_Prompt_Template = ChatPromptTemplate.from_messages([
    ("system","你是一个友好的AI助手，你的名字叫{name}"),
    ("user","你好，最近怎么样？"),
    ("ai","我很好，谢谢"),
    ("user","{user_input}"),
])

# 调用
result = Chat_Prompt_Template.format(name = "卢本伟", user_input = "2 + 2 = ? ")
print(result)
print(type(result))
# Out:
# System: 你是一个友好的AI助手，你的名字叫卢本伟
# Human: 你好，最近怎么样？
# AI: 我很好，谢谢
# Human: 2 + 2 = ?
# <class 'str'>

# %% [markdown]
# ### 2.3 format_messages()
#
# 传入参数：变量值：返回值类型：消息列表
#
# 举例：

# %%
from langchain_core.prompts import ChatPromptTemplate

Chat_Prompt_Template = ChatPromptTemplate.from_messages([
    ("system","你是一个友好的AI助手，你的名字叫{name}"),
    ("user","你好，最近怎么样？"),
    ("ai","我很好，谢谢"),
    ("user","{user_input}"),
])

# 调用
result = Chat_Prompt_Template.format_messages(name = "卢本伟", user_input = "2 + 2 = ? ")
print(result)
print(type(result))
# Out:
# [SystemMessage(content='你是一个友好的AI助手，你的名字叫卢本伟', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，最近怎么样？', additional_kwargs={}, response_metadata={}), AIMessage(content='我很好，谢谢', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='2 + 2 = ? ', additional_kwargs={}, response_metadata={})]
# <class 'list'>

# %% [markdown]
# ## 3、结合大模型的调用
#
# 举例：

# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate
from dotenv import load_dotenv
import os

# 1、提供大模型
load_dotenv(override=True)
DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")
DASHSCOPE_BASE_URL = os.getenv("DASHSCOPE_BASE_URL")

model = init_chat_model(
    model="qwen3.7-plus",
    model_provider="openai",
    # temperature=1.5,
    api_key=DASHSCOPE_API_KEY,
    base_url=DASHSCOPE_BASE_URL,
    # max_tokens=10,
)

# 2、提供提示词模板
Chat_Prompt_Template = ChatPromptTemplate.from_messages([
    ("system","你是一个友好的AI助手，你的名字叫{name}"),
    ("user","你好，最近怎么样？"),
    ("ai","我很好，谢谢"),
    ("user","{user_input}"),
])

# 调用
prompt_value = Chat_Prompt_Template.invoke({"name":"卢本伟", "user_input":"2 + 2 = ？"})
# prompt_value = result = Chat_Prompt_Template.format_messages(name = "卢本伟", user_input = "2 + 2 = ? ")

# 3、模型调用
response = model.invoke(prompt_value)
print(response)
# Out:
# content='2+2等于4啊兄弟！这题太简单了，简直是在侮辱我卢本伟的智商！十七张牌你能秒我？你能秒杀我？！给阿姨倒一杯卡布奇诺，开始你的表演！卢本伟牛逼！' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 588, 'prompt_tokens': 51, 'total_tokens': 639, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 529, 'rejected_prediction_tokens': None, 'text_tokens': 588}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0, 'text_tokens': 51}}, 'model_provider': 'openai', 'model_name': 'qwen3.7-plus', 'system_fingerprint': None, 'id': 'chatcmpl-255f75fa-1259-97b1-aa48-64d740664019', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4307-f008-7b62-9083-5c8660ff2014-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 51, 'output_tokens': 588, 'total_tokens': 639, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 529}}

# %% [markdown]
# ## 4、更丰富的初始化参数类型
#
# ### 4.1 字符串列表

# %%
from langchain_core.prompts import ChatPromptTemplate
chat_prompt_template = ChatPromptTemplate.from_messages([
    "你好，我是{name}"   # 会理解为是一个用户消息
])

chat_prompt_template.invoke({"name":"小明"})
# Out:
# ChatPromptValue(messages=[HumanMessage(content='你好，我是小明', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ### 4.2 元组列表

# %%
from langchain_core.prompts import ChatPromptTemplate
chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system","你是你个友好的ai助手"),
    ("human", "你好，我是{name}")
])

chat_prompt_template.invoke({"name":"小明"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是你个友好的ai助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，我是小明', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ### 4.3 字典列表

# %%
from langchain_core.prompts import ChatPromptTemplate
chat_prompt_template = ChatPromptTemplate.from_messages([
    {"role":"system", "content":"你是你个友好的ai助手"},
    {"role":"human", "content":"你好，我是{name}"}
])

chat_prompt_template.invoke({"name":"小明"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是你个友好的ai助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，我是小明', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ### 4.4 消息对象列表

# %%
from langchain_core.messages import SystemMessage,HumanMessage
from langchain_core.prompts import ChatPromptTemplate
chat_prompt_template = ChatPromptTemplate.from_messages([
    SystemMessage(content="你是你个友好的ai助手"),
    HumanMessage(content="你好，我是小明")
])

chat_prompt_template.invoke({})

# %% [markdown]
# 说明：消息对象中是否可以声明变量？  否！！！

# %%
from langchain_core.messages import SystemMessage,HumanMessage
from langchain_core.prompts import ChatPromptTemplate
chat_prompt_template = ChatPromptTemplate.from_messages([
    SystemMessage(content="你是你个友好的ai助手"),
    HumanMessage(content="你好，我是{name}")
])

chat_prompt_template.invoke({"name":"小明"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是你个友好的ai助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，我是{name}', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ### 4.5 BaseMessagePromptTemplate

# %%
from langchain_core.prompts import SystemMessagePromptTemplate,HumanMessagePromptTemplate
from langchain_core.prompts import ChatPromptTemplate

system_message_template = SystemMessagePromptTemplate.from_template("你是你个友好的ai助手")
human_message_template = HumanMessagePromptTemplate.from_template("你好，我是{name}")
chat_prompt_template = ChatPromptTemplate.from_messages([
    system_message_template,
    human_message_template
])


chat_prompt_template.invoke({"name":"小明"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是你个友好的ai助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，我是小明', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ### 4.6 BaseChatPromptTemplate参数列表

# %%
from langchain_core.prompts import ChatPromptTemplate

inner_chat_template1 = ChatPromptTemplate.from_messages([
    ("system", "你是你个友好的ai助手"),
])

inner_chat_template2 = ChatPromptTemplate.from_messages([
    ("human", "你好，我叫{name}")
])

chat_prompt_template = ChatPromptTemplate.from_messages([
    inner_chat_template1,
    inner_chat_template2
])


chat_prompt_template.invoke({"name":"小明"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是你个友好的ai助手', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，我叫小明', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ### 4.7 综合使用

# %%
from langchain_core.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain_core.messages import SystemMessage, HumanMessage

# 示例 1: 使用 BaseMessage（已实例化的消息）
system_msg = SystemMessage(content="你是一个AI工程师。")
human_msg = HumanMessage(content="你好！")

# 示例 2: 使用 BaseMessagePromptTemplate
system_prompt = SystemMessagePromptTemplate.from_template("你是一个{role}.")
human_prompt = HumanMessagePromptTemplate.from_template("{user_input}")

# 示例 3: 使用 BaseChatPromptTemplate（嵌套的 ChatPromptTemplate）
nested_prompt = ChatPromptTemplate.from_messages([
    ("system", "嵌套提示词")
])

prompt = ChatPromptTemplate.from_messages([
    system_msg,     # MessageLike (BaseMessage)
    human_msg,      # MessageLike (BaseMessage)
    system_prompt,  # MessageLike (BaseMessagePromptTemplate)
    human_prompt,   # MessageLike (BaseMessagePromptTemplate)
    nested_prompt,  # MessageLike (BaseChatPromptTemplate)
])
prompt.invoke({"role":"人工智能专家","user_input":"介绍一下大模型的应用场景"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是一个AI工程师。', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好！', additional_kwargs={}, response_metadata={}), SystemMessage(content='你是一个人工智能专家.', additional_kwargs={}, response_metadata={}), HumanMessage(content='介绍一下大模型的应用场景', additional_kwargs={}, response_metadata={}), SystemMessage(content='嵌套提示词', additional_kwargs={}, response_metadata={})])
