# %% [markdown]
# # 调用线上大模型
#
# ## 1. 调用具体模型厂商的API
#
# ### 1.1 调用DeepSeek官网的DeepSeek模型
#
# 调用大模型涉及到三个特别重要的参数
# base_url、model_name、api_key
#
# 举例1：将参数信息存储在.env配置文件中

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek
from langchain_openrouter import ChatOpenRouter

#1、读取.env配置文件中的信息，相关的环境变量要以.env文件中的优先
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL,
)

# 3、模型的调用
response = llm_deepseek.invoke("请用一句话介绍你自己")
print(response)

# %% [markdown]
# 举例2：是对举例1的优化

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

#1、读取.env配置文件中的信息，相关的环境变量要以.env文件中的优先
load_dotenv(override=True)

# DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
# DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    # api_key=DEEPSEEK_API_KEY,
    # api_base=DEEPSEEK_BASE_URL,
)

# 3、模型的调用
response = llm_deepseek.invoke("你好，你是谁？")
print(response.content)

# %% [markdown]
# 举例3：演示一下参数声明在代码中（不推荐）

# %%
from langchain_deepseek import ChatDeepSeek

# 1、模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key="your_api_key",
    api_base="https://api.deepseek.com",
)

# 2、模型的调用
response = llm_deepseek.invoke("你好，你是谁？")
print(response)

# %% [markdown]
# ### 1.2 通过调用智谱平台获取相关大模型
#
# 举例1：将参数信息存储在.env配置文件中 url必须是https://open.bigmodel.cn/api/paas/v4/chat/completions 不能只到v4

# %%
import os

from dotenv import load_dotenv
from langchain_community.chat_models import ChatZhipuAI

#1、读取.env配置文件中的信息，相关的环境变量要以.env文件中的优先
load_dotenv(override=True)

ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL") # https://open.bigmodel.cn/api/paas/v4/chat/completions

# 2、模型的初始化
llm_zhipuai = ChatZhipuAI(
    model="GLM-4.5-Air",
    api_key=ZHIPUAI_API_KEY,
    api_base=ZHIPUAI_BASE_URL, # https://open.bigmodel.cn/api/paas/v4/chat/completions
)

# 3、模型的调用
response = llm_zhipuai.invoke("请用一句话介绍你自己,你现在是什么大模型，什么版本")
print(response)

# %% [markdown]
# 举例2：对举例1的优化

# %%
import os

from dotenv import load_dotenv
from langchain_community.chat_models import ChatZhipuAI

#1、读取.env配置文件中的信息，相关的环境变量要以.env文件中的优先
load_dotenv(override=True)

# ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
# ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL")

# 2、模型的初始化
llm_zhipuai = ChatZhipuAI(
    model="GLM-4.5-Air",
    # api_key=ZHIPUAI_API_KEY,
    # api_base=ZHIPUAI_BASE_URL,
)

# 3、模型的调用
response = llm_zhipuai.invoke("请用一句话介绍你自己,你现在是什么大模型，什么版本")
print(response)

# %% [markdown]
# 举例3：和deepseek例3一致（不演示）

# %% [markdown]
# ### 1.3 通过阿里云百炼平台获取相关大模型
# 举例1：将参数信息存储在.env配置文件中

# %%
import os

from dotenv import load_dotenv
from langchain_community.chat_models import ChatTongyi

#1、读取.env配置文件中的信息，相关的环境变量要以.env文件中的优先
load_dotenv(override=True)

DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")
DASHSCOPE_BASE_URL = os.getenv("DASHSCOPE_BASE_URL")

# 2、模型的初始化
llm_tongyi = ChatTongyi(
    model="qwen-max",
    api_key=DASHSCOPE_API_KEY,
    api_base=DASHSCOPE_BASE_URL,
)

# 3、模型的调用
response = llm_tongyi.invoke("请用一句话介绍你自己")
print(response.content)

# %% [markdown]
# 举例2：和上面一致方法（不演示）

# %% [markdown]
# 举例3：和上面一致方法（不演示）

# %% [markdown]
# ## 2. 兼容的写法
#
# 使用ChatOpenAI
#
# 举例1：调用deepseek官网提供的大模型

# %%
import os

from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("请用一句话介绍你自己").content)
# Out:
# 我是DeepSeek，由深度求索公司创造的AI助手，免费使用、支持文件上传与长上下文处理，随时准备用热情细腻的方式为你答疑解惑！

# %% [markdown]
# 举例2：调用智谱官网提供的大模型
# url必须是https://open.bigmodel.cn/api/paas/v4  后缀他自己会补上

# %%
import os

from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL") # https://open.bigmodel.cn/api/paas/v4

# 获取大模型
model = ChatOpenAI(
    model="GLM-4.5-Air",
    api_key=ZHIPUAI_API_KEY,
    base_url=ZHIPUAI_BASE_URL, # https://open.bigmodel.cn/api/paas/v4
)

print(model.invoke("请用一句话介绍你自己").content)

# %% [markdown]
# 举例3：调用阿里云百炼平台提供的大模型

# %%
import os

from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")
DASHSCOPE_BASE_URL = os.getenv("DASHSCOPE_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="qwen-max",
    api_key=DASHSCOPE_API_KEY,
    base_url=DASHSCOPE_BASE_URL,
)

print(model.invoke("请用一句话介绍你自己").content)

# %% [markdown]
# ## 3. 使用中转平台
#
# ### 3.1 使用OpenRouter
#
# 举例1: 调用国内大模型，比如deepseek

# %%
import os

from langchain_openrouter import ChatOpenRouter
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = ChatOpenRouter(
    model="deepseek/deepseek-v4-flash",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE,
)

print(model.invoke("请用一句话介绍你自己").content)

# %% [markdown]
# 举例2：调用国外大模型，比如gpt

# %%
import os

from langchain_openrouter import ChatOpenRouter
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = ChatOpenRouter(
    model="openai/gpt-4o-mini",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE,
)

print(model.invoke("请用一句话介绍你自己，告诉我你是什么模型，什么版本").content)

# %% [markdown]
# ### 3.2 使用CloseAI
#
# 举例1：调用国内大模型。比如deepseek

# %%
import os

from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_API_BASE = os.getenv("CLOSEAI_API_BASE")

# 获取大模型
model = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_API_BASE,
)

print(model.invoke("请用一句话介绍你自己，告诉我你是什么模型，什么版本").content)

# %% [markdown]
# 举例2：调用国内大模型。比如gpt

# %%
import os

from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_API_BASE = os.getenv("CLOSEAI_API_BASE")

# 获取大模型
model = ChatOpenAI(
    model="gpt-5.4-mini",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_API_BASE,
)

print(model.invoke("请用一句话介绍你自己，告诉我你是什么模型，什么版本").content)

# %% [markdown]
# ## 4. 使用langchain1.x的统一方式
#
# 使用 init_chat_model()
#
# 举例1：调用deepseek官网的deepseek模型

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model = init_chat_model(
    # model="deepseek-v4-flash",
    # model_provider="deepseek",
    # 或者
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("请用一句话介绍你自己，告诉我你是什么模型，什么版本").content)

# %% [markdown]
# 举例2： 调用OpenRouter平台的大模型

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = init_chat_model(
    # model="openai/gpt-4o-mini",
    # model_provider="openrouter",
    # 或者
    model="openrouter:openai/gpt-4o-mini",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE,
)

print(model.invoke("请用一句话介绍你自己，告诉我你是什么模型，什么版本").content)

# %% [markdown]
# ## 5. 小结
#
# DeepSeek官网的DeepSeek模型：可以调用ChatDeepSeek()、ChatOpenAI()、
# init_chat_model()三种方式
#
#
# 阿里云百炼平台的DeepSeek模型：可以调用ChatTongyi()、ChatOpenAI()、init_chat_model()
# 三种方式
#
#
# OpenRouter平台的DeepSeek模型：可以调用ChatOpenRouter()、ChatOpenAI()、
# init_chat_model()三种方式
#
#
# CloseAPI平台的DeepSeek模型：可以调用ChatOpenAI()、init_chat_model() 两种方式
